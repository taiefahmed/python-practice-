# %% [markdown]
# #no.1:Print “hello world” from a variable.

# %%
A="hello world"
print(A)
# Out:
# hello world

# %% [markdown]
# #no.2: Input your name in a variable and print “Hello [your name]”

# %%
A=input("enter your name : ")
print("hello",A)
# Out:
# enter your name : Taief
# hello Taief

# %% [markdown]
# #no.3: Given two integer numbers X and Y. Print the summation and multiplication and
# subtraction and division of these 2 numbers.

# %%
A=(int)(input("enter number : "))
B=(int)(input("enter another number : "))
print("summation : ",A+B)
print("multiplication : ",A*B)
print("subtraction : ",A-B)
print("division : ",A/B)1
# Out:
# enter number : 20
# enter another number : 10
# summation :  30
# multiplication :  200
# subtraction :  10
# division :  2.0

# %% [markdown]
# #no.4: Given two float numbers X and Y. Print the summation and multiplication and subtraction and division of these 2 numbers.

# %%
A=(float)(input("enter number : "))
B=(float)(input("enter another number : "))
print("summation : ",A+B)
print("multiplication : ",A*B)
print("subtraction : ",A-B)
print("division : ",A/B)
# Out:
# enter number : 4
# enter another number : 8
# summation :  12.0
# multiplication :  32.0
# subtraction :  -4.0
# division :  0.5

# %% [markdown]
# #no.5: Given four numbers A, B, C and D. Print the result of the following equation : X = (A * B) - (C * D).
# Print "Difference = " without quotes followed by the equation result.

# %%
A=(int)(input("enter 1st number : "))
B=(int)(input("enter 2nd number : "))
C=(int)(input("enter 3rd number : "))
D=(int)(input("enter 4th number : "))
X = (A * B) - (C * D)
print("Difference",X)
# Out:
# enter 1st number : 5
# enter 2nd number : 6
# enter 3rd number : 4
# enter 4th number : 3
# Difference 18

# %% [markdown]
# #no.6: Given two numbers N and M. Print the summation of their last digits.

# %%
A=(int)(input("enter the number : "))
B=(int)(input("enter the number : "))
print("The Summation of Last Number : ",(A%10)+(B%10))
# Out:
# enter the number : 20
# enter the number : 25
# The Summation of Last Number :  5

# %% [markdown]
# #no.7: Given a Number N corresponding to a person's age (in days). Print his age in years, months and days, followed by its respective message "years", "months","days".
# Note: consider the whole year has 365 days and 30 days per month.

# %%
Y=(int)(input("Enter person's age (in days): "))
print(Y//365,"years,",(Y%365)//30,"months,",(Y%365)%30,"days")
# Out:
# Enter person's age (in days): 370
# 1 years, 0 months, 5 days

# %% [markdown]
# #No.8: Calculate an Average of 5 integer variables.

# %%
print("enter 5 numbers : ")
A= (int) (input())
B= (int)(input())
C= (int)(input())
D= (int)(input())
E= (int)(input())
print("Average : ",(A+B+C+D+E)/5)
# Out:
# enter 5 numbers :
# 10
# 20
# 30
# 40
# 50
# Average :  30.0

# %% [markdown]
# #no.9: Given a number R calculate the area of a circle using the following formula:
# Area = π * R2.
# Note: consider π = 3.141592653.

# %%
R=(int)(input("Enter the value of R : "))
pi=3.1416
print("Area : ",pi*R*R)
# Out:
# Enter the value of R : 9
# Area :  254.4696

# %% [markdown]
# #no.10. Print the first digit of a 6 digits number. Ex: x=103457, [First digit is 1]

# %%
x=(int)(input("Enter 6 digits number: "))
print("First digit is : ",x//100000)
# Out:
# Enter 6 digits number: 203940
# First digit is :  2
